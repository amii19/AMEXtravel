# %%
import pandas as pd

# %%
data=pd.read_csv("problem_4_traveler_raw.csv")

# %%
data
# Out:
#         PNR origination_city destination_city orig_city_cd dest_city_cd  \
# 0    921597              PHX              MIA          PHX          MIA
# 1    921597              MIA              PUJ          MIA          PUJ
# 2    921597              PUJ              MIA          PUJ          MIA
# 3    921597              MIA              PHX          MIA          PHX
# 4    492751              PHX              SAN          PHX          SAN
# ..      ...              ...              ...          ...          ...
# 129  335664              EWR              PHX          EWR          PHX
# 130  435290              PHX              MIA          PHX          MIA
# 131  435290              MIA              BDA          MIA          BDA
# 132  435290              PHX              MIA          PHX          MIA
# 133  435290              MIA              BDA          MIA          BDA
#
#      origination_lat  origination_lon  destination_lat  destination_lon  \
# ...

# %%
total_trip_spend= data["fl_grfare_usd_am"].sum().round(2)
total_trip_spend
# Out:
# 125735.74

# %%
total_mile_count=data['fl_mile_ct'].sum().round(2)

# %%
num_valid_trip=data['fl_valid_id'].sum()

# %%
print(data["origination_city"].value_counts().head())
print(data["destination_city"].value_counts().head())
print("based on above it seems like PHX is traveler's home city")
# Out:
# PHX    33
# LON    28
# EWR    11
# WAS     7
# MSY     5
# Name: origination_city, dtype: int64
# PHX    37
# LON    25
# EWR     8
# MIA     5
# WAS     5
# Name: destination_city, dtype: int64
# based on above it seems like PHX is traveler's home city

# %%
# Out:
# PHX    37
# LON    25
# EWR     8
# MIA     5
# WAS     5
# NBO     5
# DFW     4
# NYC     4
# SFO     4
# MSY     4
# DEN     4
# EDI     3
# MAD     3
# SEA     2
# AMS     2
# EYW     2
# BDA     2
# LAX     1
# PUJ     1
# NAS     1
# BNA     1
# BOS     1
# SJD     1
# ATL     1
# CLT     1
# SAN     1
# MUC     1
# NCE     1
# MEX     1
# FRA     1
# DEL     1
# LIH     1
# Name: destination_city, dtype: int64
